# %% [markdown]
# # Atividade Prática 07: Polimorfismo
#
# Nesta atividade prática, vamos retornar à classe Usuario que usamos nas atividades anteriores. Para implementar o princípio do polimorfismo, criaremos uma classe chamada Usuario. A partir dela criaremos algumas classes como: para calcular o número de pontuações que um usuário tem, e o número de artigos que ele criou ou editou. Baseado nesta classe (Usuario), vamos criar as classes Autor e Editor, e ambas calcularão o número de pontuações com o método calcPontuacao(), embora o valor calculado seja diferente entre estas duas classes.

# %% [markdown]
# 1. Acrescente na classe Usuario métodos para definir e obter o número de artigos:
#
#   a) setNumeroDeArtigos(self, nart)
#
#   b) getNumeroDeArtigos(self)
#
#   Obs: variável nart deve ser um inteiro

# %% [markdown]
# 2. Acrescente à classe o método chamado calcPontuacao(), que realiza os cálculos das pontuações separadamente para cada classe.

# %%
# Este é o esqueleto deste usuário

class Usuario():
  def __init__ (self, numeroArtigos):
    self._numeroArtigos = numeroArtigos
  _pontos = 0

  def setNumeroArtigos (self, nart): #int
      self._numeroArtigos = nart

  def getNumeroArtigos (self):
    return self._numeroArtigos
  
  def calcPontuacao (self):
    pass

# %% [markdown]
# 3. Crie uma classe chamada Autor que herda da classe de Usuario. Nesta classe (Autor) crie um método chamado calcPontuacao() que retorna o número de pontuações usando o seguinte cálculo: **numeroArtigos x 10 + 20**

# %%
class Autor (Usuario):

  def calcPontuacao (self):
    nart = self.getNumeroArtigos()
    pontos = ((nart*10) + 20)
    return f"Para {nart} o autor tem {pontos} pontos"

# %% [markdown]
# 4. Agora crie também uma classe chamada Editor que herda da classe Usuario. Nesta classe (Editor), crie um método chamado calcPontuacao() que retorne o número de pontuações usando o seguinte cálculo: **numeroArtigos x 6 + 15**

# %%
class Editor (Usuario):

  def calcPontuacao (self):
    nart = self.getNumeroArtigos()
    self._pontos = nart*6+15
    return f"Para {nart} o editor tem {self._pontos} pontos"

# %% [markdown]
# 5. Crie um objeto chamado autor1, a partir da classe Autor. Agora defina o número de artigos como 8 e imprima as pontuações obtidas pelo autor.

# %%
autor1 = Autor(8)
print (autor1.calcPontuacao())
# Out:
# Para 8 o autor tem 100 pontos

# %% [markdown]
# 6. Crie outro objeto chamado editor1, a partir da classe Editor. Agora defina o número de artigos para 15 e imprima as pontuações que o editor ganhou.

# %%
editor1 = Editor(15)
print (editor1.calcPontuacao())
# Out:
# Para 15 o editor tem 105 pontos
